# %% [markdown]
# # NYC Open Data API Demo
# ### by Abu Nayeem

# %%
import pandas as pd
import requests

#Agency_Name
#Borough President of Queens

#https://data.cityofnewyork.us/resource/wewp-mm3p.json

# %% [markdown]
# Request the Data

# %%
#url='https://data.cityofnewyork.us/resource/erm2-nwe9.json'
#response = requests.get(url)
#data = response.json()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 2
#       1 url='https://data.cityofnewyork.us/resource/erm2-nwe9.json'
# ----> 2 response = requests.get(url)
#       3 data = response.json()
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:703, in Session.send(self, request, **kwargs)
#     700 start = preferred_clock()
#     702 # Send the request
# --> 703 r = adapter.send(request, **kwargs)
#     705 # Total elapsed time of the request (approximately)
#     706 elapsed = preferred_clock() - start
#
# File ~\anaconda3\Lib\site-packages\requests\adapters.py:589, in HTTPAdapter.send(self, request, stream, timeout, verify, cert, proxies)
#     586     timeout = TimeoutSauce(connect=timeout, read=timeout)
#     588 try:
# --> 589     resp = conn.urlopen(
#     590         method=request.method,
#     591         url=url,
#     592         body=request.body,
#     593         headers=request.headers,
#     594         redirect=False,
#     595         assert_same_host=False,
#     596         preload_content=False,
#     597         decode_content=False,
#     598         retries=self.max_retries,
#     599         timeout=timeout,
#     600         chunked=chunked,
#     601     )
#     603 except (ProtocolError, OSError) as err:
#     604     raise ConnectionError(err, request=request)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:789, in HTTPConnectionPool.urlopen(self, method, url, body, headers, retries, redirect, assert_same_host, timeout, pool_timeout, release_conn, chunked, body_pos, preload_content, decode_content, **response_kw)
#     786 response_conn = conn if not release_conn else None
#     788 # Make the request on the HTTPConnection object
# --> 789 response = self._make_request(
#     790     conn,
#     791     method,
#     792     url,
#     793     timeout=timeout_obj,
#     794     body=body,
#     795     headers=headers,
#     796     chunked=chunked,
#     797     retries=retries,
#     798     response_conn=response_conn,
#     799     preload_content=preload_content,
#     800     decode_content=decode_content,
#     801     **response_kw,
#     802 )
#     804 # Everything went great!
#     805 clean_exit = True
#
# File ~\anaconda3\Lib\site-packages\urllib3\connectionpool.py:536, in HTTPConnectionPool._make_request(self, conn, method, url, body, headers, retries, timeout, chunked, response_conn, preload_content, decode_content, enforce_content_length)
#     534 # Receive the response from the server
#     535 try:
# --> 536     response = conn.getresponse()
#     537 except (BaseSSLError, OSError) as e:
#     538     self._raise_timeout(err=e, url=url, timeout_value=read_timeout)
#
# File ~\anaconda3\Lib\site-packages\urllib3\connection.py:464, in HTTPConnection.getresponse(self)
#     461 from .response import HTTPResponse
#     463 # Get the response from http.client.HTTPConnection
# --> 464 httplib_response = super().getresponse()
#     466 try:
#     467     assert_header_parsing(httplib_response.msg)
#
# File ~\anaconda3\Lib\http\client.py:1428, in HTTPConnection.getresponse(self)
#    1426 try:
#    1427     try:
# -> 1428         response.begin()
#    1429     except ConnectionError:
#    1430         self.close()
#
# File ~\anaconda3\Lib\http\client.py:331, in HTTPResponse.begin(self)
#     329 # read until we get a non-100 response
#     330 while True:
# --> 331     version, status, reason = self._read_status()
#     332     if status != CONTINUE:
#     333         break
#
# File ~\anaconda3\Lib\http\client.py:292, in HTTPResponse._read_status(self)
#     291 def _read_status(self):
# --> 292     line = str(self.fp.readline(_MAXLINE + 1), "iso-8859-1")
#     293     if len(line) > _MAXLINE:
#     294         raise LineTooLong("status line")
#
# File ~\anaconda3\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
url1= 'https://data.cityofnewyork.us/resource/wewp-mm3p.json?$limit=38000000'
url1='https://data.cityofnewyork.us/resource/wewp-mm3p.json?$limit=38000000&$where=date>="2024-01-01"'

data1 = requests.get(url1).json()
data1=pd.DataFrame(data1)
len(data1)
data1.head(5)
#data1.tail(5)
# Out:
#    unique_id                     date         time                date_time  \
# 0  157455811  2024-01-01T00:00:00.000  12:12:21 AM  2024-01-01T00:12:21.000
# 1  157455852  2024-01-01T00:00:00.000  12:21:26 AM  2024-01-01T00:21:26.000
# 2  157456056  2024-01-01T00:00:00.000   1:05:48 AM  2024-01-01T01:05:48.000
# 3  157456557  2024-01-01T00:00:00.000   3:27:46 AM  2024-01-01T03:27:46.000
# 4  157456724  2024-01-01T00:00:00.000   4:23:52 AM  2024-01-01T04:23:52.000
#
#           inquiry_name                                  brief_description
# 0  Fireworks Complaint  Report the sale, use, storage, or transport of...
# 1  Noise from Neighbor                           Report a noisy neighbor.
# 2       New Year's Day               Monday, January 1 is New Year's Day.
# 3  Noise from Neighbor                           Report a noisy neighbor.
# 4  Noise from Neighbor                           Report a noisy neighbor.

# %% [markdown]
# How many rows have we received?

# %%
#len(data1)
#data1.to_csv('301_2024raw.csv', index=False)

# %%
df=data1
df['DateTime']= pd.to_datetime(df['date_time']) # Create new column called DateTime
df['Year']= df['DateTime'].dt.year #create year column
df['DayofWeek']=df['DateTime'].dt.dayofweek #create day of the week column where default 0=Monday
df['Weekend'] = df['DayofWeek'].apply(lambda x: 1 if (x>4)  else 0) #Create a weekend category
df['Month'] = df['DateTime'].dt.month # Create Month Category
df['Day'] = df['DateTime'].dt.day #Create Day of the Current month
df['DayYear'] = df['DateTime'].dt.dayofyear  #Create Day of the year (0-365)
df['Hour'] = df['DateTime'].dt.hour  #Create Day of the year (0-365)
#df['Day_Max'] = df.iloc[0,-1] #selects uptodate day; NOTE: the data is sorted chronologically

df.head(5)
# Out:
#    unique_id                     date         time                date_time  \
# 0  157455811  2024-01-01T00:00:00.000  12:12:21 AM  2024-01-01T00:12:21.000
# 1  157455852  2024-01-01T00:00:00.000  12:21:26 AM  2024-01-01T00:21:26.000
# 2  157456056  2024-01-01T00:00:00.000   1:05:48 AM  2024-01-01T01:05:48.000
# 3  157456557  2024-01-01T00:00:00.000   3:27:46 AM  2024-01-01T03:27:46.000
# 4  157456724  2024-01-01T00:00:00.000   4:23:52 AM  2024-01-01T04:23:52.000
#
#           inquiry_name                                  brief_description  \
# 0  Fireworks Complaint  Report the sale, use, storage, or transport of...
# 1  Noise from Neighbor                           Report a noisy neighbor.
# 2       New Year's Day               Monday, January 1 is New Year's Day.
# 3  Noise from Neighbor                           Report a noisy neighbor.
# 4  Noise from Neighbor                           Report a noisy neighbor.
#
#    Dex            DateTime  Day  Year  DayofWeek  Weekend  Month  DayYear  \
# 0    1 2024-01-01 00:12:21    1  2024          0        0      1        1
# 1    1 2024-01-01 00:21:26    1  2024          0        0      1        1
# 2    1 2024-01-01 01:05:48    1  2024          0        0      1        1
# 3    1 2024-01-01 03:27:46    1  2024          0        0      1        1
# 4    1 2024-01-01 04:23:52    1  2024          0        0      1        1
#
#    Day_Max  Hour
# 0        1     0
# 1        1     0
# 2        1     1
# 3        1     3
# 4        1     4

# %%
print(df.DayofWeek.value_counts())
print(df.Weekend.value_counts())
print(df.Day.value_counts())
print(df.Hour.value_counts())
# Out:
# DayofWeek
# 1    528865
# 0    522027
# 3    497020
# 2    486670
# 4    458246
# 5    209292
# 6    191687
# Name: count, dtype: int64
# Weekend
# 0    2492828
# 1     400979
# Name: count, dtype: int64
# Day
# 22    109013
# 29    108071
# 8     108055
# 12    107600
# 5     106784
# 1     105745
# 2     105500
# 26    105183
# 15    103050
# 16    100128
# 9      97944
# 23     97222
# 20     95029
# 6      92552
# 13     91915
# 17     91762
# 19     91656
# 18     91334
# 10     90595
# 25     90166
# 11     89797
# 21     89634
# 3      89434
# 7      88299
# 24     88176
# 14     88022
# 4      84715
# 27     83966
# 28     76496
# 30     70850
# 31     55114
# Name: count, dtype: int64
# Hour
# 11    256889
# 10    254234
# 12    246158
# 9     245391
# 13    244229
# 14    244012
# 15    235257
# 16    204692
# 8     146557
# 17    127200
# 18    106294
# 19     87305
# 20     76406
# 7      65641
# 21     60138
# 22     49893
# 23     48731
# 0      43069
# 6      39979
# 1      31505
# 5      23607
# 2      22083
# 3      17662
# 4      16875
# Name: count, dtype: int64

# %%
m= df.query('inquiry_name=="Mayor" and DayYear==90')
m.DayYear.value_counts()
m
df.query('inquiry_name=="Illegal Parking" and DayYear==90').shape
# Out:
# (254, 16)

# %%
#Convert Date to Datetime!
import datetime
from datetime import datetime

df['DateTime']= pd.to_datetime(df['date_time'])

df['Day']= df['DateTime'].dt.day
print(df['Day'].value_counts())

df['DateTime']= pd.to_datetime(df['Date']) # Create new column called DateTime
df['Year']= df['DateTime'].dt.year #create year column
df['DayofWeek']=df['DateTime'].dt.dayofweek #create day of the week column where default 0=Monday
df['Weekend'] = df['DayofWeek'].apply(lambda x: 1 if (x>4)  else 0) #Create a weekend category
df['Month'] = df['DateTime'].dt.month # Create Month Category
df['Day'] = df['DateTime'].dt.day #Create Day of the Current month
df['DayYear'] = df['DateTime'].dt.dayofyear  #Create Day of the year (0-365)
df['Day_Max'] = df.iloc[0,-1] #selects uptodate day; NOTE: the data is sorted chronologically

# %%
# Displays up to 30 columns
pd.set_option('display.max_columns', 30)
pd.set_option('display.max_rows', 50)
pd.set_option('display.max_rows', None)


data1['Dex']=1
p=['inquiry_name', 'Dex']
c= data1[p].groupby(['inquiry_name',]).sum().reset_index() #the reset index is important for AssignedSiteID to separate
c.rename(columns={'Dex':'Count'},inplace= True)
c.query('Count>10000').sort_values(by=['Count'])

['Blocked Sidewalk or Street',	'Pothole or Cave-In on Street', 'Illegal Parking']
# Out:
#                                            inquiry_name  Count
# 1144                                              Mayor  10073
# 160                          Blocked Sidewalk or Street  10194
# 1492                            Property Deed or Record  10652
# 1680  Senior Citizen Homeowners' Exemption (SCHE) Re...  10827
# 1025                             Injured or Sick Animal  11013
# 1568                    Rent Freeze Program for Seniors  11016
# 987                   IDNYC Documents Required to Apply  11261
# 1660            School Tax Relief for Homeowners (STAR)  11539
# 1461                       Pothole or Cave-In on Street  12038
# 495                     Dangerous Location or Situation  12053
# 704                               Fallen Tree or Branch  12258
# 1500                       Property Tax Bill Assistance  12543
# 1946                Traffic Signal Complaint or Request  12583
# 189                     Building Construction Complaint  12811
# 741                              Fire Hydrant Complaint  12906
# 655                     Elevator or Escalator Complaint  12959
# 1601                                 SNAP (Food Stamps)  13404
# 1505                    Property Tax Payment Assistance  13810
# 1550                             Rat or Mouse Complaint  13912
# 862                             HEAP Cooling Assistance  14460
# 700           Fair Fares NYC Card Replacement or Refund  14797
# 1566                        Rent Freeze Program Renewal  14906
# 699                                      Fair Fares NYC  15325
# 536              Department of Finance Business Centers  15649
# 1679        Senior Citizen Homeowners' Exemption (SCHE)  15889
# 951                                   Homeless Shelters  15895
# 1957  Trash, Recycling, and Compost Collection Schedule  16255
# 949                          Homeless Shelter Complaint  17529
# 1306                      Noise from Street or Sidewalk  17962
# 872        HPD Code Enforcement Borough Service Centers  18574
# 216                                   Buses and Subways  19569
# 1565                     Rent Freeze Program Assistance  19594
# 1906                                  Tenant Harassment  20049
# 1445                          Police Precincts and PSAs  23181
# 228                               CFC and Freon Removal  23424
# 967             Housing Court for Tenants and Landlords  23745
# 1504                               Property Tax Payment  23889
# 1035                              Jail System Complaint  24796
# 555                                Directory Assistance  26754
# 1379    Parking Ticket or Camera Violation Payment Plan  27060
# 12                                    Abandoned Vehicle  28889
# 1082                                   Legal Assistance  29977
# 1376         Parking Ticket or Camera Violation Dispute  30278
# 1373      Parking Ticket or Camera Violation Assistance  30364
# 153                             Birth Certificate Order  32713
# 1499                                  Property Tax Bill  32782
# 206                                  Bulk Item Disposal  32883
# 334                      City Agency or Worker Feedback  38525
# 909   Heat or Hot Water Complaint in a Residential B...  39469
# 1378         Parking Ticket or Camera Violation Payment  43570
# 988                             IDNYC Municipal ID Card  44686
# 1303                                Noise from Neighbor  49482
# 1687                             Service Request Status  54665
# 159                                    Blocked Driveway  66984
# 996                                     Illegal Parking  70531
# 1933                                      Towed Vehicle  71458
# 1381          Parking Ticket or Camera Violation Status  81741
# 64                      Apartment Maintenance Complaint  83314

# %% [markdown]
# Let's Filter the Data and Increase Limit

# %% [markdown]
# We can either edit the query link:

# %%
url= 'https://data.cityofnewyork.us/resource/wewp-mm3p.json?$limit=38000000&$where=Agency_Name="Borough President of Queens"'

data = requests.get(url).json()
data=pd.DataFrame(data)
len(data)

#Agency_Name
# Borough President of Queens

#https://data.cityofnewyork.us/resource/wewp-mm3p.json
#data.inquiry_name.value_counts()

#https://data.cityofnewyork.us/resource/wewp-mm3p.json?$query=SELECT%0A%20%20%60unique_id%60%2C%0A%20%20%60date%60%2C%0A%20%20%60time%60%2C%0A%20%20%60date_time%60%2C%0A%20%20%60agency%60%2C%0A%20%20%60agency_name%60%2C%0A%20%20%60inquiry_name%60%2C%0A%20%20%60brief_description%60%2C%0A%20%20%60call_resolution%60%0AWHERE%20%60date%60%20%3E%20%222024-01-01T14%3A15%3A31%22%20%3A%3A%20floating_timestamp

#WHERE%20%60date%60%20%3E%20%222024-01-01T14%3A15%3A31%22%20%3A%3A%20floating_timestamp

#0%60brief_description%60%2C%0A%20%20%60call_resolution%60%0A


0%2C%0A%20%20%60time%60%2C%0A%20%20%60date_time%60%2C%0A%20%20%60agency%60%2C%0A%20%20%60agency_name%60%2C%0A%20%20%60inquiry_name%60%2C%0A%20%20%60brief_description%60%2C%0A%20%20%60call_resolution%60%0AWHERE%20%60date%60%20%3E%20%222024-01-01T14%3A15%3A31%22%20%3A%3A%20floating_timestamp
# Out:
# Street Ownership - Queens        145
# Division Information Provided     29
# Division Transfer                 17
# Division Referral                  7
# Staff Information Provided         1
# Name: inquiry_name, dtype: int64

# %%
#url= 'https://data.cityofnewyork.us/resource/erm2-nwe9.json?$limit=38000000&$where=agency="NYPD" AND created_date > "2024-03-01" AND descriptor="Blocked Bike Lane"'

url='https://data.cityofnewyork.us/resource/wewp-mm3p.json?$query=SELECT%0A%20%20%60unique_id%60%2C%0A%20%20%60date%60%2C%0A%20%20%60time%60%2C%0A%20%20%60date_time%60%2C%0A%20%20%60agency%60%2C%0A%20%20%60agency_name%60%2C%0A%20%20%60inquiry_name%60%2C%0A%20%20%60brief_description%60%2C%0A%20%20%60call_resolution%60%0AWHERE%20%60date%60%20%3E%20%222024-01-01T14%3A15%3A31%22%20%3A%3A%20floating_timestamp'

url='https://data.cityofnewyork.us/resource/wewp-mm3p.json?$limit=38000000&$where=date>="2024-01-01"'


data = requests.get(url).json()
data=pd.DataFrame(data)
print(len(data))


print(data.head(5))

data.inquiry_name.value_counts() >10


data['Dex']=1
p=['inquiry_name', 'Dex']
c= data[p].groupby(['inquiry_name',]).sum().reset_index() #the reset index is important for AssignedSiteID to separate
c.rename(columns={'Dex':'Count'},inplace= True)
c.query('Count>10')
#Agency_Name
# Borough President of Queens

#https://data.cityofnewyork.us/resource/wewp-mm3p.json
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[14], line 8
#       3 url='https://data.cityofnewyork.us/resource/wewp-mm3p.json?$query=SELECT%0A%20%20%60unique_id%60%2C%0A%20%20%60date%60%2C%0A%20%20%60time%60%2C%0A%20%20%60date_time%60%2C%0A%20%20%60agency%60%2C%0A%20%20%60agency_name%60%2C%0A%20%20%60inquiry_name%60%2C%0A%20%20%60brief_description%60%2C%0A%20%20%60call_resolution%60%0AWHERE%20%60date%60%20%3E%20%222024-01-01T14%3A15%3A31%22%20%3A%3A%20floating_timestamp'
#       5 url='https://data.cityofnewyork.us/resource/wewp-mm3p.json?$limit=38000000&$where=date>="2024-01-01"'
# ----> 8 data = requests.get(url).json()
#       9 data=pd.DataFrame(data)
#      10 print(len(data))
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:73, in get(url, params, **kwargs)
#      62 def get(url, params=None, **kwargs):
#      63     r"""Sends a GET request.
#      64
#      65     :param url: URL for the new :class:`Request` object.
#    (...)
#      70     :rtype: requests.Response
#      71     """
# ---> 73     return request("get", url, params=params, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\api.py:59, in request(method, url, **kwargs)
#      55 # By using the 'with' statement we are sure the session is closed, thus we
#      56 # avoid leaving sockets open which can trigger a ResourceWarning in some
#      57 # cases, and look like a memory leak in others.
#      58 with sessions.Session() as session:
# ---> 59     return session.request(method=method, url=url, **kwargs)
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:589, in Session.request(self, method, url, params, data, headers, cookies, files, auth, timeout, allow_redirects, proxies, hooks, stream, verify, cert, json)
#     584 send_kwargs = {
#     585     "timeout": timeout,
#     586     "allow_redirects": allow_redirects,
#     587 }
#     588 send_kwargs.update(settings)
# --> 589 resp = self.send(prep, **send_kwargs)
#     591 return resp
#
# File ~\anaconda3\Lib\site-packages\requests\sessions.py:746, in Session.send(self, request, **kwargs)
#     743         pass
#     745 if not stream:
# --> 746     r.content
#     748 return r
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:902, in Response.content(self)
#     900         self._content = None
#     901     else:
# --> 902         self._content = b"".join(self.iter_content(CONTENT_CHUNK_SIZE)) or b""
#     904 self._content_consumed = True
#     905 # don't need to release the connection; that's been handled by urllib3
#     906 # since we exhausted the data.
#
# File ~\anaconda3\Lib\site-packages\requests\models.py:820, in Response.iter_content.<locals>.generate()
#     818 if hasattr(self.raw, "stream"):
#     819     try:
# --> 820         yield from self.raw.stream(chunk_size, decode_content=True)
#     821     except ProtocolError as e:
#     822         raise ChunkedEncodingError(e)
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:1057, in HTTPResponse.stream(self, amt, decode_content)
#    1041 """
#    1042 A generator wrapper for the read() method. A call will block until
#    1043 ``amt`` bytes have been read from the connection or until the
#    (...)
#    1054     'content-encoding' header.
#    1055 """
#    1056 if self.chunked and self.supports_chunked_reads():
# -> 1057     yield from self.read_chunked(amt, decode_content=decode_content)
#    1058 else:
#    1059     while not is_fp_closed(self._fp) or len(self._decoded_buffer) > 0:
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:1209, in HTTPResponse.read_chunked(self, amt, decode_content)
#    1207 if self.chunk_left == 0:
#    1208     break
# -> 1209 chunk = self._handle_chunk(amt)
#    1210 decoded = self._decode(
#    1211     chunk, decode_content=decode_content, flush_decoder=False
#    1212 )
#    1213 if decoded:
#
# File ~\anaconda3\Lib\site-packages\urllib3\response.py:1146, in HTTPResponse._handle_chunk(self, amt)
#    1144     self.chunk_left = None
#    1145 elif self.chunk_left is not None and amt < self.chunk_left:
# -> 1146     value = self._fp._safe_read(amt)  # type: ignore[union-attr]
#    1147     self.chunk_left = self.chunk_left - amt
#    1148     returned_chunk = value
#
# File ~\anaconda3\Lib\http\client.py:640, in HTTPResponse._safe_read(self, amt)
#     633 def _safe_read(self, amt):
#     634     """Read the number of bytes requested.
#     635
#     636     This function should be used when <amt> bytes "should" be present for
#     637     reading. If the bytes are truly not available (due to EOF), then the
#     638     IncompleteRead exception can be used to detect the problem.
#     639     """
# --> 640     data = self.fp.read(amt)
#     641     if len(data) < amt:
#     642         raise IncompleteRead(data, amt-len(data))
#
# File ~\anaconda3\Lib\socket.py:707, in SocketIO.readinto(self, b)
#     705 while True:
#     706     try:
# --> 707         return self._sock.recv_into(b)
#     708     except timeout:
#     709         self._timeout_occurred = True
#
# File ~\anaconda3\Lib\ssl.py:1252, in SSLSocket.recv_into(self, buffer, nbytes, flags)
#    1248     if flags != 0:
#    1249         raise ValueError(
#    1250           "non-zero flags not allowed in calls to recv_into() on %s" %
#    1251           self.__class__)
# -> 1252     return self.read(nbytes, buffer)
#    1253 else:
#    1254     return super().recv_into(buffer, nbytes, flags)
#
# File ~\anaconda3\Lib\ssl.py:1104, in SSLSocket.read(self, len, buffer)
#    1102 try:
#    1103     if buffer is not None:
# -> 1104         return self._sslobj.read(len, buffer)
#    1105     else:
#    1106         return self._sslobj.read(len)
#
# KeyboardInterrupt:

# %%
len(data)
#data.date.value_counts()
data.dtypes

#Convert Date to Datetime!
import datetime
from datetime import datetime

data['DateTime']= pd.to_datetime(data['date_time'])

data['Day']= data['DateTime'].dt.day
print(data['Day'].value_counts())
#Students['BirthMonth']= Students['BirthDateTime'].dt.month
#Students['BirthDay']= Students['BirthDateTime'].dt.dayofyear


df['DateTime']= pd.to_datetime(df['Date']) # Create new column called DateTime
df['Year']= df['DateTime'].dt.year #create year column
df['DayofWeek']=df['DateTime'].dt.dayofweek #create day of the week column where default 0=Monday
df['Weekend'] = df['DayofWeek'].apply(lambda x: 1 if (x>4)  else 0) #Create a weekend category
df['Month'] = df['DateTime'].dt.month # Create Month Category
df['Day'] = df['DateTime'].dt.day #Create Day of the Current month
df['DayYear'] = df['DateTime'].dt.dayofyear  #Create Day of the year (0-365)
df['Day_Max'] = df.iloc[0,-1] #selects uptodate day; NOTE: the data is sorted chronologically
# Out:
# 5     106779
# 1     100651
# 2      98553
# 22     95238
# 8      94782
# 29     94520
# 12     91941
# 26     89911
# 3      89099
# 15     88744
# 16     86311
# 18     86046
# 17     85919
# 25     84943
# 4      84715
# 11     84343
# 10     84256
# 23     84098
# 9      83861
# 24     82315
# 20     80962
# 6      78620
# 19     76789
# 13     76318
# 21     76286
# 28     75972
# 7      74685
# 14     72782
# 30     70392
# 27     69223
# 31     49533
# Name: Day, dtype: int64

# %% [markdown]
# Or we can use SQL:

# %% [markdown]
# To group the data with SQL:

# %%
query= '''
      SELECT *
      WHERE agency="NYPD"
            AND created_date>"2024-03-01"
            AND descriptor="Blocked Bike Lane"
      '''

url=f'https://data.cityofnewyork.us/resource/erm2-nwe9.json?$query={query}'

data= requests.get(url).json()
data=pd.DataFrame(data)

data.head(5)


# Sample Run

#"2014-10-13T00:00:00.000" 
#https://data.cityofnewyork.us/resource/wewp-mm3p.json?$query=SELECT%0A%20%20%60unique_id%60%2C%0A%20%20%60date%60%2C%0A%20%20%60time%60%2C%0A%20%20%60date_time%60%2C%0A%20%20%60agency%60%2C%0A%20%20%60agency_name%60%2C%0A%20%20%60inquiry_name%60%2C%0A%20%20%60brief_description%60%2C%0A%20%20%60call_resolution%60%0AORDER%20BY%20%60date%60%20DESC%20NULL%20LAST

query1= '''
      SELECT *
      WHERE date> "2024-06-10T00:00:00.000"
          AND inquiry_name="Gas Leak"
      '''

url1=f'https://data.cityofnewyork.us/resource/wewp-mm3p.json?$query={query1}'

data1= requests.get(url1).json()
data1=pd.DataFrame(data1)

data1.head(5)
# Out:
#    unique_id                     date        time                date_time  \
# 0  159381288  2024-06-11T00:00:00.000  2:52:17 AM  2024-06-11T02:52:17.000
# 1  159381360  2024-06-11T00:00:00.000  4:07:09 AM  2024-06-11T04:07:09.000
# 2  159381649  2024-06-11T00:00:00.000  6:46:24 AM  2024-06-11T06:46:24.000
# 3  159381682  2024-06-11T00:00:00.000  6:53:47 AM  2024-06-11T06:53:47.000
# 4  159381745  2024-06-11T00:00:00.000  7:10:28 AM  2024-06-11T07:10:28.000
#
#                                         inquiry_name  \
# 0                     City Agency or Worker Feedback
# 1                                           Gas Leak
# 2  Heat or Hot Water Complaint in a Residential B...
# 3                            Birth Certificate Order
# 4                                      Date and Time
#
#                                    brief_description
# 0  Give a complaint, compliment, or comment on th...
# 1  Call 911 to report a gas leak or any gas-relat...
# 2  Report a problem with heat or hot water in a r...
# 3                 Get a copy of a birth certificate.
# 4        Find out today's date and the current time.

# %%
query1= '''
      SELECT *
      WHERE inquiry_name="Gas Leak"
          AND date> "2023-06-10T00:00:00.000"
      '''

# date> "2024-06-10T00:00:00.000"

url1=f'https://data.cityofnewyork.us/resource/wewp-mm3p.json?$query={query1}'

data1= requests.get(url1).json()
data1=pd.DataFrame(data1)

data1
# Out:
#      unique_id                     date         time                date_time  \
# 0    158239314  2024-03-05T00:00:00.000   3:24:20 PM  2024-03-05T15:24:20.000
# 1    158248749  2024-03-06T00:00:00.000  11:42:11 AM  2024-03-06T11:42:11.000
# 2    156310471  2023-09-26T00:00:00.000   4:41:00 AM  2023-09-26T04:41:00.000
# 3    156310656  2023-09-26T00:00:00.000   6:46:46 AM  2023-09-26T06:46:46.000
# 4    158279708  2024-03-08T00:00:00.000   1:47:11 PM  2024-03-08T13:47:11.000
# ..         ...                      ...          ...                      ...
# 995  156775809  2023-11-02T00:00:00.000   9:19:50 AM  2023-11-02T09:19:50.000
# 996  156776375  2023-11-02T00:00:00.000   9:32:12 AM  2023-11-02T09:32:12.000
# 997  156778137  2023-11-02T00:00:00.000  10:52:17 AM  2023-11-02T10:52:17.000
# 998  156783963  2023-11-02T00:00:00.000   2:56:42 PM  2023-11-02T14:56:42.000
# 999  156785057  2023-11-02T00:00:00.000   3:47:02 PM  2023-11-02T15:47:02.000
#
#     inquiry_name                                  brief_description
# 0       Gas Leak  Call 911 to report a gas leak or any gas-relat...
# 1       Gas Leak  Call 911 to report a gas leak or any gas-relat...
# 2       Gas Leak  Call 911 to report a gas leak or any gas-relat...
# 3       Gas Leak  Call 911 to report a gas leak or any gas-relat...
# 4       Gas Leak  Call 911 to report a gas leak or any gas-relat...
# ..           ...                                                ...
# 995     Gas Leak  Call 911 to report a gas leak or any gas-relat...
# 996     Gas Leak  Call 911 to report a gas leak or any gas-relat...
# 997     Gas Leak  Call 911 to report a gas leak or any gas-relat...
# 998     Gas Leak  Call 911 to report a gas leak or any gas-relat...
# 999     Gas Leak  Call 911 to report a gas leak or any gas-relat...
#
# [1000 rows x 6 columns]

# %%
query= '''
      SELECT
        incident_zip,
        COUNT(unique_key) AS count
      WHERE complaint_type = "Illegal Parking"
            AND created_date>"2024-03-01"
            AND borough = "BROOKLYN"
      GROUP BY incident_zip
      '''

url=f'https://data.cityofnewyork.us/resource/erm2-nwe9.json?$query={query}'

data= requests.get(url).json()
data=pd.DataFrame(data)

data
# Out:
#    incident_zip count
# 0         11201   773
# 1         11203   126
# 2         11204   265
# 3         11205   401
# 4         11206   127
# 5         11207   190
# 6         11208   316
# 7         11209   415
# 8         11210   177
# 9         11211   127
# 10        11212   130
# 11        11213   134
# 12        11214   519
# 13        11215   471
# 14        11216   137
# 15        11217   380
# 16        11218   303
# 17        11219   256
# 18        11220   365
# 19        11221   146
# 20        11222   398
# 21        11223   386
# 22        11224    88
# 23        11225   174
# 24        11226   264
# 25        11228   202
# 26        11229   416
# 27        11230   434
# 28        11231   345
# 29        11232   159
# 30        11233   137
# 31        11234   269
# 32        11235   564
# 33        11236   166
# 34        11237   160
# 35        11238   264
# 36        11239   139
# 37        11241     3
# 38        11242     3
# 39        11249    56
# 40          NaN     1
